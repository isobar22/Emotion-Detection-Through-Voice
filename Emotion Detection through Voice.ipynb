# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk(r"D:\Emotion Detection Through Voice\TESS Toronto emotional speech set data\TESS Toronto emotional speech set data"):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['D:\\Emotion Detection Through Voice\\TESS Toronto emotional speech set data\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_back_angry.wav',
#  'D:\\Emotion Detection Through Voice\\TESS Toronto emotional speech set data\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bar_angry.wav',
#  'D:\\Emotion Detection Through Voice\\TESS Toronto emotional speech set data\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_base_angry.wav',
#  'D:\\Emotion Detection Through Voice\\TESS Toronto emotional speech set data\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bath_angry.wav',
#  'D:\\Emotion Detection Through Voice\\TESS Toronto emotional speech set data\\TESS Toronto emotional speech set data\\OAF_angry\\OAF_bean_angry.wav']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech  label
# 0  D:\Emotion Detection Through Voice\TESS Toront...  angry
# 1  D:\Emotion Detection Through Voice\TESS Toront...  angry
# 2  D:\Emotion Detection Through Voice\TESS Toront...  angry
# 3  D:\Emotion Detection Through Voice\TESS Toront...  angry
# 4  D:\Emotion Detection Through Voice\TESS Toront...  angry

# %%
df['label'].value_counts()
# Out:
# label
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()
    
def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275578e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228456e+00, -5.57366073e-01, -1.83255339e+00,  2.02101693e-01,
#         7.27550924e-01,  1.31773746e+00,  2.88633800e+00,  2.85579062e+00,
#        -4.71292162e+00, -4.43651009e+00, -1.62115920e+00, -1.02398405e+01,
#        -7.55126190e+00, -1.79688060e+00, -7.03765249e+00,  9.43658352e+00,
#         8.35585403e+00,  2.17123604e+01,  1.92169895e+01,  2.03489285e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722253e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486879e+00,  2.50996375e+00, -1.82390714e+00,
#         4.86896276e+00,  9.31392384e+00,  2.08914971e+00, -1.90649128e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.65600866, -32.74544, ...
# 2       [-429.79196, 46.12401, 1.5550476, -0.21709447,...
# 3       [-403.46118, 76.32369, -12.531776, -22.288858,...
# 4       [-434.05756, 77.4455, 10.865501, 16.092943, 8....
#                               ...
# 2795    [-406.4805, 80.379875, 32.462395, 46.579094, -...
# 2796    [-426.90918, 102.54756, 24.800041, 43.048096, ...
# 2797    [-378.50494, 80.91062, 35.300533, 39.74792, -4...
# 2798    [-434.8618, 89.906364, 28.373262, 39.57707, -2...
# 2799    [-421.8341, 70.69788, 32.476387, 45.642555, 4....
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 256)                 │         264,192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │             455 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 305,799 (1.17 MB)
#  Trainable params: 305,799 (1.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - accuracy: 0.4084 - loss: 1.4769 - val_accuracy: 0.3232 - val_loss: 2.3491
# Epoch 2/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━
50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 102ms/step - accuracy: 0.9961 - loss: 0.0211 - val_accuracy: 0.6143 - val_loss: 3.2137
# Epoch 29/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.9852 - loss: 0.0414 - val_accuracy: 0.4964 - val_loss: 3.2663
# Epoch 30/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.9960 - loss: 0.0169 - val_accuracy: 0.5125 - val_loss: 4.1460
# Epoch 31/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.9987 - loss: 0.0052 - val_accuracy: 0.5589 - val_loss: 3.4068
# Epoch 32/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 183ms/step - accuracy: 0.9738 - loss: 0.0985 - val_accuracy: 0.4554 - val_loss: 3.9636
# Epoch 33/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9772 - loss: 0.1010 - val_accuracy: 0.4036 - val_loss: 3.2253
# Epoch 34/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.9955 - loss: 0.0144 - val_accuracy: 0.4054 - val_loss: 3.1800
# Epoch 35/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.9990 - loss: 0.0065 - val_accuracy: 0.4357 - val_loss: 3.5008
# Epoch 36/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.9992 - loss: 0.0053 - val_accuracy: 0.4911 - val_loss: 3.2161
# Epoch 37/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9991 - loss: 0.0048 - val_accuracy: 0.4161 - val_loss: 3.9090
# Epoch 38/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 138ms/step - accuracy: 0.9974 - loss: 0.0041 - val_accuracy: 0.4714 - val_loss: 3.6920
# Epoch 39/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.5411 - val_loss: 3.3135
# Epoch 40/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - accuracy: 0.9971 - loss: 0.0100 - val_accuracy: 0.3661 - val_loss: 4.7948
# Epoch 41/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.9985 - loss: 0.0057 - val_accuracy: 0.5393 - val_loss: 3.0105
# Epoch 42/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 176ms/step - accuracy: 0.9983 - loss: 0.0048 - val_accuracy: 0.4732 - val_loss: 3.7370
# Epoch 43/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.9955 - loss: 0.0143 - val_accuracy: 0.4339 - val_loss: 4.0096
# Epoch 44/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - accuracy: 0.9988 - loss: 0.0075 - val_accuracy: 0.5268 - val_loss: 4.1192
# Epoch 45/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.4893 - val_loss: 4.0546
# Epoch 46/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - accuracy: 1.0000 - loss: 7.5546e-04 - val_accuracy: 0.5089 - val_loss: 4.0440
# Epoch 47/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 6s 163ms/step - accuracy: 1.0000 - loss: 3.7136e-04 - val_accuracy: 0.5196 - val_loss: 4.0600
# Epoch 48/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 11s 170ms/step - accuracy: 1.0000 - loss: 4.7099e-04 - val_accuracy: 0.5321 - val_loss: 4.0184
# Epoch 49/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 7s 203ms/step - accuracy: 1.0000 - loss: 3.7336e-04 - val_accuracy: 0.5196 - val_loss: 4.1708
# Epoch 50/50
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 159ms/step - accuracy: 1.0000 - loss: 3.0927e-04 - val_accuracy: 0.5161 - val_loss: 4.1410

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
